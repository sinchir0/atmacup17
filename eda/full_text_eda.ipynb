# %%
import pandas as pd

data = pd.read_csv(
    "../trained_models/e020-auxiliary-loss/valid_dataset_e020-auxiliary-loss.csv"
)

# %%
data

# %%
data["Title"] = data["Title"].fillna("")
data["Review Text"] = data["Review Text"].fillna("")

data["full_text"] = data["Title"] + " " + data["Review Text"]

data["Title_word_num"] = data["Title"].apply(lambda x: len(x.split()))
data["Review_word_num"] = data["Review Text"].apply(lambda x: len(x.split()))
data["full_text_word_num"] = data["full_text"].apply(lambda x: len(x.split()))

# %%
data["full_text_word_num"].value_counts()
# Out:
# full_text_word_num
# 0      155
# 2       79
# 100     61
# 43      56
# 3       55
#       ...
# 113      5
# 115      4
# 114      4
# 117      1
# 116      1
# Name: count, Length: 118, dtype: int64

# %%
data[data["full_text_word_num"] == 0]
# Out:
#       index  Clothing ID  Age Title Review Text  Rating  label  \
# 12       50            3   37                         4      1
# 26      111            5   38                         3      1
# 33      124            6   43                         3      1
# 41      144            7   32                         4      1
# 60      201            7   52                         2      1
# ...     ...          ...  ...   ...         ...     ...    ...
# 3198   9582          226   42                         4      1
# 3260   9779          226   65                         4      1
# 3262   9788          226   69                         4      1
# 3275   9834          228   71                         2      0
# 3277   9839          229   54                         4      1
#
#       Positive Feedback Count Division Name Department Name Class Name  fold  \
# 12                          0       General         Dresses    Dresses     0
# 26                          0       General            Tops   Sweaters     0
# 33                          0       General         Bottoms     Skirts     0
# 41                          0       General            Tops    Blouses     0
# 60                          0       General            Tops    Blouses     0
# ...                       ...           ...             ...        ...   ...
# 3198                        0       General         Dresses    Dresses     0
# 3260                        0       General         Dresses    Dresses     0
# 3262                        0       General         Dresses    Dresses     0
# 3275                       44       General         Jackets  Outerwear     0
# 3277                        3       General         Bottoms      Jeans     0
#
#       valid_pred full_text  Title_word_num  Review_word_num  \
# 12      0.940790                         0                0
# 26      0.940298                         0                0
# 33      0.939692                         0                0
# 41      0.939360                         0                0
# 60      0.939081                         0                0
# ...          ...       ...             ...              ...
# 3198    0.940844                         0                0
# 3260    0.940953                         0                0
# 3262    0.940681                         0                0
# 3275    0.939248                         0                0
# 3277    0.940735                         0                0
#
#       full_text_word_num
# 12                     0
# 26                     0
# 33                     0
# 41                     0
# 60                     0
# ...                  ...
# 3198                   0
# 3260                   0
# 3262                   0
# 3275                   0
# 3277                   0
#
# [155 rows x 17 columns]

# %%
data[data["full_text_word_num"] == 0]
