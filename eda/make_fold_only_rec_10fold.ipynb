# %%
import polars as pl

train = pl.read_csv("/home/shinichiro.saito/atmacup17/data/train_with_index.csv")

# %%
train["Recommended IND"].value_counts(normalize=True)
# Out:
# shape: (2, 2)
# ┌─────────────────┬────────────┐
# │ Recommended IND ┆ proportion │
# │ ---             ┆ ---        │
# │ i64             ┆ f64        │
# ╞═════════════════╪════════════╡
# │ 0               ┆ 0.1798     │
# │ 1               ┆ 0.8202     │
# └─────────────────┴────────────┘

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold

fold_arr = np.zeros(train.height)
sgkf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

for idx, (_, val_idx) in enumerate(sgkf.split(train, train["Recommended IND"])):
    fold_arr[val_idx] = idx

train = train.with_columns(pl.Series(fold_arr).cast(pl.Int64).alias("fold"))

# %%
# idとlabelをdictにして保存する
id_fold_dict = dict(zip(train["index"], train["fold"]))

# %%
# jsonで保存する
import json

with open(
    f"/home/shinichiro.saito/atmacup17/data/rec_stratified_10fold.json", "w"
) as f:
    json.dump(id_fold_dict, f)

# %%
id_fold_dict
# Out:
# {0: 8,
#  1: 9,
#  2: 6,
#  3: 1,
#  4: 3,
#  5: 3,
#  6: 1,
#  7: 8,
#  8: 6,
#  9: 8,
#  10: 6,
#  11: 5,
#  12: 6,
#  13: 5,
#  14: 8,
#  15: 9,
#  16: 6,
#  17: 9,
#  18: 2,
#  19: 6,
#  20: 1,
#  21: 9,
#  22: 0,
#  23: 7,
#  24: 2,
#  25: 4,
#  26: 6,
#  27: 5,
#  28: 2,
#  29: 6,
#  30: 8,
#  31: 0,
#  32: 2,
#  33: 8,
#  34: 8,
#  35: 4,
#  36: 8,
#  37: 2,
#  38: 3,
#  39: 7,
#  40: 9,
#  41: 6,
#  42: 8,
#  43: 7,
#  44: 7,
#  45: 5,
#  46: 9,
#  47: 7,
#  48: 8,
#  49: 5,
#  50: 2,
#  51: 8,
#  52: 5,
#  53: 6,
#  54: 6,
#  55: 8,
#  56: 7,
#  57: 8,
#  58: 8,
#  59: 3,
#  60: 7,
#  61: 5,
#  62: 6,
#  63: 2,
#  64: 4,
#  65: 2,
#  66: 5,
#  67: 3,
#  68: 8,
#  69: 3,
#  70: 8,
#  71: 4,
#  72: 2,
#  73: 9,
#  74: 5,
#  75: 6,
#  76: 4,
#  77: 9,
#  78: 6,
#  79: 8,
#  80: 0,
#  81: 6,
#  82: 3,
#  83: 1,
#  84: 5,
#  85: 9,
#  86: 4,
#  87: 5,
#  88: 7,
#  89: 3,
#  90: 6,
#  91: 6,
#  92: 5,
#  93: 3,
#  94: 9,
#  95: 9,
#  96: 2,
#  97: 3,
#  98: 2,
#  99: 4,
#  100: 7,
#  101: 2,
#  102: 4,
#  103: 0,
#  104: 4,
#  105: 2,
#  106: 8,
#  107: 3,
#  108: 4,
#  109: 2,
#  110: 4,
#  111: 0,
#  112: 2,
#  113: 1,
#  114: 2,
#  115: 8,
#  116: 2,
#  117: 8,
#  118: 0,
#  119: 4,
#  120: 9,
#  121: 9,
#  122: 1,
#  123: 3,
#  124: 3,
#  125: 3,
#  126: 0,
#  127: 2,
#  128: 7,
#  129: 4,
#  130: 7,
#  131: 0,
#  132: 6,
#  133: 7,
#  134: 7,
#  135: 8,
#  136: 1,
#  137: 7,
#  138: 7,
#  139: 4,
#  140: 8,
#  141: 9,
#  142: 1,
#  143: 0,
#  144: 0,
#  145: 5,
#  146: 9,
#  147: 8,
#  148: 6,
#  149: 5,
#  150: 6,
#  151: 2,
#  152: 5,
#  153: 6,
#  154: 0,
#  155: 3,
#  156: 3,
#  157: 3,
#  158: 1,
#  159: 9,
#  160: 3,
#  161: 2,
#  162: 7,
#  163: 8,
#  164: 5,
#  165: 8,
#  166: 1,
#  167: 4,
#  168: 9,
#  169: 9,
#  170: 5,
#  171: 1,
#  172: 3,
#  173: 3,
#  174: 4,
#  175: 5,
#  176: 0,
#  177: 0,
#  178: 4,
#  179: 3,
#  180: 8,
#  181: 2,
#  182: 4,
#  183: 4,
#  184: 3,
#  185: 5,
#  186: 3,
#  187: 4,
#  188: 5,
#  189: 7,
#  190: 3,
#  191: 3,
#  192: 9,
#  193: 3,
#  194: 1,
#  195: 6,
#  196: 3,
#  197: 7,
#  198: 5,
#  199: 2,
#  200: 1,
#  201: 1,
#  202: 8,
#  203: 6,
#  204: 2,
#  205: 7,
#  206: 8,
#  207: 1,
#  208: 7,
#  209: 0,
#  210: 6,
#  211: 1,
#  212: 8,
#  213: 7,
#  214: 0,
#  215: 3,
#  216: 0,
#  217: 0,
#  218: 4,
#  219: 3,
#  220: 5,
#  221: 6,
#  222: 5,
#  223: 0,
#  224: 0,
#  225: 3,
#  226: 6,
#  227: 6,
#  228: 4,
#  229: 3,
#  230: 3,
#  231: 2,
#  232: 8,
#  233: 7,
#  234: 8,
#  235: 0,
#  236: 2,
#  237: 2,
#  238: 5,
#  239: 1,
#  240: 5,
#  241: 7,
#  242: 1,
#  243: 3,
#  244: 3,
#  245: 8,
#  246: 8,
#  247: 7,
#  248: 0,
#  249: 1,
#  250: 2,
#  251: 4,
#  252: 9,
#  253: 9,
#  254: 2,
#  255: 0,
#  256: 7,
#  257: 0,
#  258: 6,
#  259: 8,
#  260: 0,
#  261: 5,
#  262: 1,
#  263: 3,
#  264: 4,
#  265: 3,
#  266: 1,
#  267: 6,
#  268: 5,
#  269: 7,
#  270: 7,
#  271: 0,
#  272: 6,
#  273: 2,
#  274: 0,
#  275: 6,
#  276: 2,
#  277: 6,
#  278: 3,
#  279: 0,
#  280: 7,
#  281: 3,
#  282: 6,
#  283: 8,
#  284: 5,
#  285: 9,
#  286: 3,
#  287: 2,
#  288: 9,
#  289: 6,
#  290: 5,
#  291: 8,
#  292: 8,
#  293: 2,
#  294: 1,
#  295: 2,
#  296: 4,
#  297: 2,
#  298: 1,
#  299: 7,
#  300: 2,
#  301: 6,
#  302: 9,
#  303: 5,
#  304: 0,
#  305: 7,
#  306: 8,
#  307: 5,
#  308: 9,
#  309: 7,
#  310: 4,
#  311: 6,
#  312: 9,
#  313: 6,
#  314: 0,
#  315: 9,
#  316: 5,
#  317: 7,
#  318: 5,
#  319: 0,
#  320: 7,
#  321: 8,
#  322: 2,
#  323: 9,
#  324: 9,
#  325: 0,
#  326: 4,
#  327: 4,
#  328: 6,
#  329: 0,
#  330: 6,
#  331: 2,
#  332: 3,
#  333: 9,
#  334: 1,
#  335: 1,
#  336: 1,
#  337: 6,
#  338: 8,
#  339: 0,
#  340: 3,
#  341: 3,
#  342: 5,
#  343: 0,
#  344: 7,
#  345: 5,
#  346: 7,
#  347: 1,
#  348: 1,
#  349: 8,
#  350: 7,
#  351: 2,
#  352: 5,
#  353: 6,
#  354: 6,
#  355: 0,
#  356: 8,
#  357: 2,
#  358: 5,
#  359: 1,
#  360: 0,
#  361: 0,
#  362: 2,
#  363: 1,
#  364: 8,
#  365: 1,
#  366: 6,
#  367: 3,
#  368: 3,
#  369: 7,
#  370: 0,
#  371: 9,
#  372: 6,
#  373: 6,
#  374: 2,
#  375: 3,
#  376: 7,
#  377: 6,
#  378: 7,
#  379: 1,
#  380: 3,
#  381: 0,
#  382: 1,
#  383: 5,
#  384: 4,
#  385: 0,
#  386: 7,
#  387: 5,
#  388: 7,
#  389: 6,
#  390: 1,
#  391: 8,
#  392: 6,
#  393: 6,
#  394: 5,
#  395: 5,
#  396: 8,
#  397: 5,
#  398: 9,
#  399: 2,
#  400: 3,
#  401: 1,
#  402: 3,
#  403: 7,
#  404: 7,
#  405: 2,
#  406: 3,
#  407: 5,
#  408: 2,
#  409: 0,
#  410: 0,
#  411: 8,
#  412: 5,
#  413: 5,
#  414: 8,
#  415: 8,
#  416: 2,
#  417: 3,
#  418: 3,
#  419: 2,
#  420: 0,
#  421: 5,
#  422: 3,
#  423: 0,
#  424: 2,
#  425: 9,
#  426: 1,
#  427: 8,
#  428: 3,
#  429: 5,
#  430: 1,
#  431: 6,
#  432: 1,
#  433: 7,
#  434: 5,
#  435: 5,
#  436: 5,
#  437: 6,
#  438: 2,
#  439: 4,
#  440: 8,
#  441: 7,
#  442: 3,
#  443: 3,
#  444: 5,
#  445: 5,
#  446: 4,
#  447: 1,
#  448: 1,
#  449: 5,
#  450: 3,
#  451: 1,
#  452: 0,
#  453: 1,
#  454: 5,
#  455: 2,
#  456: 5,
#  457: 6,
#  458: 4,
#  459: 4,
#  460: 5,
#  461: 2,
#  462: 2,
#  463: 9,
#  464: 0,
#  465: 7,
#  466: 2,
#  467: 0,
#  468: 9,
#  469: 6,
#  470: 7,
#  471: 4,
#  472: 9,
#  473: 0,
#  474: 3,
#  475: 3,
#  476: 3,
#  477: 1,
#  478: 9,
#  479: 1,
#  480: 7,
#  481: 5,
#  482: 0,
#  483: 7,
#  484: 5,
#  485: 7,
#  486: 3,
#  487: 8,
#  488: 5,
#  489: 4,
#  490: 1,
#  491: 0,
#  492: 2,
#  493: 0,
#  494: 6,
#  495: 1,
#  496: 0,
#  497: 5,
#  498: 8,
#  499: 6,
#  500: 8,
#  501: 3,
#  502: 5,
#  503: 5,
#  504: 1,
#  505: 9,
#  506: 3,
#  507: 7,
#  508: 8,
#  509: 3,
#  510: 3,
#  511: 8,
#  512: 6,
#  513: 2,
#  514: 9,
#  515: 1,
#  516: 6,
#  517: 4,
#  518: 5,
#  519: 0,
#  520: 1,
#  521: 7,
#  522: 2,
#  523: 2,
#  524: 4,
#  525: 9,
#  526: 4,
#  527: 5,
#  528: 5,
#  529: 8,
#  530: 4,
#  531: 2,
#  532: 5,
#  533: 2,
#  534: 9,
#  535: 1,
#  536: 2,
#  537: 7,
#  538: 6,
#  539: 9,
#  540: 0,
#  541: 1,
#  542: 3,
#  543: 7,
#  544: 5,
#  545: 9,
#  546: 8,
#  547: 4,
#  548: 3,
#  549: 3,
#  550: 2,
#  551: 0,
#  552: 4,
#  553: 9,
#  554: 2,
#  555: 6,
#  556: 7,
#  557: 1,
#  558: 4,
#  559: 3,
#  560: 5,
#  561: 8,
#  562: 9,
#  563: 6,
#  564: 8,
#  565: 0,
#  566: 4,
#  567: 8,
#  568: 1,
#  569: 3,
#  570: 8,
#  571: 9,
#  572: 2,
#  573: 4,
#  574: 2,
#  575: 9,
#  576: 5,
#  577: 6,
#  578: 8,
#  579: 1,
#  580: 2,
#  581: 5,
#  582: 6,
#  583: 1,
#  584: 7,
#  585: 6,
#  586: 9,
#  587: 1,
#  588: 7,
#  589: 2,
#  590: 6,
#  591: 1,
#  592: 0,
#  593: 9,
#  594: 8,
#  595: 7,
#  596: 4,
#  597: 2,
#  598: 3,
#  599: 9,
#  600: 9,
#  601: 6,
#  602: 5,
#  603: 7,
#  604: 9,
#  605: 1,
#  606: 3,
#  607: 1,
#  608: 5,
#  609: 9,
#  610: 2,
#  611: 7,
#  612: 4,
#  613: 8,
#  614: 8,
#  615: 1,
#  616: 9,
#  617: 5,
#  618: 4,
#  619: 8,
#  620: 8,
#  621: 4,
#  622: 6,
#  623: 3,
#  624: 4,
#  625: 0,
#  626: 0,
#  627: 9,
#  628: 4,
#  629: 6,
#  630: 6,
#  631: 2,
#  632: 7,
#  633: 4,
#  634: 0,
#  635: 1,
#  636: 5,
#  637: 5,
#  638: 1,
#  639: 0,
#  640: 4,
#  641: 2,
#  642: 5,
#  643: 9,
#  644: 1,
#  645: 4,
#  646: 0,
#  647: 1,
#  648: 9,
#  649: 9,
#  650: 3,
#  651: 8,
#  652: 6,
#  653: 0,
#  654: 9,
#  655: 2,
#  656: 8,
#  657: 1,
#  658: 1,
#  659: 1,
#  660: 5,
#  661: 8,
#  662: 4,
#  663: 9,
#  664: 5,
#  665: 7,
#  666: 0,
#  667: 0,
#  668: 2,
#  669: 0,
#  670: 1,
#  671: 5,
#  672: 9,
#  673: 3,
#  674: 8,
#  675: 8,
#  676: 8,
#  677: 6,
#  678: 4,
#  679: 1,
#  680: 8,
#  681: 4,
#  682: 5,
#  683: 5,
#  684: 3,
#  685: 7,
#  686: 4,
#  687: 6,
#  688: 5,
#  689: 0,
#  690: 9,
#  691: 1,
#  692: 9,
#  693: 6,
#  694: 0,
#  695: 5,
#  696: 0,
#  697: 9,
#  698: 3,
#  699: 6,
#  700: 2,
#  701: 1,
#  702: 4,
#  703: 1,
#  704: 2,
#  705: 4,
#  706: 5,
#  707: 4,
#  708: 6,
#  709: 8,
#  710: 9,
#  711: 7,
#  712: 9,
#  713: 4,
#  714: 8,
#  715: 6,
#  716: 9,
#  717: 8,
#  718: 6,
#  719: 6,
#  720: 7,
#  721: 0,
#  722: 0,
#  723: 6,
#  724: 0,
#  725: 7,
#  726: 1,
#  727: 8,
#  728: 7,
#  729: 1,
#  730: 7,
#  731: 2,
#  732: 2,
#  733: 3,
#  734: 7,
#  735: 7,
#  736: 0,
#  737: 4,
#  738: 9,
#  739: 8,
#  740: 2,
#  741: 0,
#  742: 8,
#  743: 0,
#  744: 7,
#  745: 5,
#  746: 9,
#  747: 5,
#  748: 0,
#  749: 8,
#  750: 7,
#  751: 7,
#  752: 4,
#  753: 5,
#  754: 7,
#  755: 2,
#  756: 3,
#  757: 3,
#  758: 3,
#  759: 5,
#  760: 6,
#  761: 6,
#  762: 6,
#  763: 6,
#  764: 6,
#  765: 2,
#  766: 0,
#  767: 7,
#  768: 0,
#  769: 9,
#  770: 8,
#  771: 4,
#  772: 5,
#  773: 2,
#  774: 1,
#  775: 4,
#  776: 7,
#  777: 5,
#  778: 9,
#  779: 9,
#  780: 7,
#  781: 8,
#  782: 4,
#  783: 0,
#  784: 5,
#  785: 0,
#  786: 6,
#  787: 2,
#  788: 6,
#  789: 2,
#  790: 0,
#  791: 1,
#  792: 1,
#  793: 4,
#  794: 7,
#  795: 3,
#  796: 4,
#  797: 7,
#  798: 0,
#  799: 4,
#  800: 7,
#  801: 9,
#  802: 2,
#  803: 8,
#  804: 7,
#  805: 9,
#  806: 9,
#  807: 7,
#  808: 5,
#  809: 3,
#  810: 3,
#  811: 8,
#  812: 7,
#  813: 9,
#  814: 2,
#  815: 7,
#  816: 4,
#  817: 1,
#  818: 1,
#  819: 7,
#  820: 9,
#  821: 9,
#  822: 9,
#  823: 0,
#  824: 3,
#  825: 0,
#  826: 5,
#  827: 3,
#  828: 0,
#  829: 7,
#  830: 4,
#  831: 5,
#  832: 9,
#  833: 5,
#  834: 3,
#  835: 6,
#  836: 1,
#  837: 5,
#  838: 5,
#  839: 6,
#  840: 9,
#  841: 5,
#  842: 5,
#  843: 1,
#  844: 1,
#  845: 1,
#  846: 2,
#  847: 2,
#  848: 6,
#  849: 8,
#  850: 8,
#  851: 9,
#  852: 0,
#  853: 1,
#  854: 5,
#  855: 0,
#  856: 3,
#  857: 6,
#  858: 3,
#  859: 9,
#  860: 6,
#  861: 3,
#  862: 0,
#  863: 1,
#  864: 4,
#  865: 3,
#  866: 9,
#  867: 3,
#  868: 7,
#  869: 2,
#  870: 7,
#  871: 0,
#  872: 6,
#  873: 9,
#  874: 4,
#  875: 5,
#  876: 6,
#  877: 7,
#  878: 7,
#  879: 6,
#  880: 8,
#  881: 7,
#  882: 5,
#  883: 1,
#  884: 6,
#  885: 1,
#  886: 2,
#  887: 3,
#  888: 5,
#  889: 4,
#  890: 8,
#  891: 2,
#  892: 7,
#  893: 4,
#  894: 5,
#  895: 2,
#  896: 1,
#  897: 8,
#  898: 1,
#  899: 3,
#  900: 8,
#  901: 2,
#  902: 0,
#  903: 5,
#  904: 5,
#  905: 9,
#  906: 2,
#  907: 3,
#  908: 6,
#  909: 3,
#  910: 3,
#  911: 4,
#  912: 5,
#  913: 9,
#  914: 7,
#  915: 7,
#  916: 4,
#  917: 7,
#  918: 9,
#  919: 6,
#  920: 0,
#  921: 3,
#  922: 8,
#  923: 7,
#  924: 4,
#  925: 0,
#  926: 0,
#  927: 6,
#  928: 4,
#  929: 7,
#  930: 8,
#  931: 7,
#  932: 8,
#  933: 6,
#  934: 0,
#  935: 8,
#  936: 6,
#  937: 8,
#  938: 0,
#  939: 7,
#  940: 2,
#  941: 5,
#  942: 4,
#  943: 4,
#  944: 7,
#  945: 3,
#  946: 7,
#  947: 7,
#  948: 0,
#  949: 5,
#  950: 6,
#  951: 4,
#  952: 7,
#  953: 9,
#  954: 2,
#  955: 5,
#  956: 8,
#  957: 1,
#  958: 1,
#  959: 9,
#  960: 0,
#  961: 4,
#  962: 8,
#  963: 0,
#  964: 5,
#  965: 1,
#  966: 3,
#  967: 9,
#  968: 6,
#  969: 2,
#  970: 1,
#  971: 7,
#  972: 8,
#  973: 9,
#  974: 3,
#  975: 5,
#  976: 1,
#  977: 9,
#  978: 0,
#  979: 0,
#  980: 0,
#  981: 6,
#  982: 0,
#  983: 9,
#  984: 3,
#  985: 5,
#  986: 2,
#  987: 5,
#  988: 4,
#  989: 7,
#  990: 1,
#  991: 9,
#  992: 9,
#  993: 7,
#  994: 7,
#  995: 0,
#  996: 2,
#  997: 9,
#  998: 6,
#  999: 7,
#  ...}
