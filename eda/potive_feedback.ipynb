# %%
import pandas as pd

data = pd.read_csv("../data/train_with_index.csv")

# %%
import seaborn as sns

sns.histplot(
    data=data, x="Positive Feedback Count", hue="Recommended IND", stat="probability"
);

# %%
# Recommendedされているやつの方が数字が多い
