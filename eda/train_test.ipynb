# %%
import pandas as pd

# %%
train = pd.read_csv("../data/train_with_index.csv")
test = pd.read_csv("../data/test_with_index.csv")

# %%
train["full_text"] = train["Title"] + " " + train["Review Text"]
test["full_text"] = test["Title"] + " " + test["Review Text"]

# %%
set(train["full_text"]) & set(test["full_text"])
# Out:
# {nan}

# %%
set(train["Title"]) & set(test["Title"])
# Out:
# {'??this',
#  'A bit big',
#  'A disappointment',
#  'A keeper!',
#  'A new favorite!',
#  'Absolutely adorable',
#  'Absolutely adorable!',
#  'Absolutely beautiful',
#  'Absolutely gorgeous',
#  'Absolutely perfect',
#  'Absolutely stunning!',
#  'Adorable',
#  'Adorable - better in person!',
#  'Adorable and comfortable',
#  'Adorable dress',
#  'Adorable top',
#  'Adorable top!',
#  'Adorable!',
#  'Adorbs',
#  'Almost great',
#  'Almost perfect',
#  'Amazing',
#  'Amazing jacket!',
#  'Amazing top',
#  'Amazing!',
#  'Amazing!!',
#  'Another beautiful byron lars',
#  'Another winner!',
#  'As pictured',
#  'Awesome',
#  'Awesome dress',
#  'Awesome dress!',
#  'Awesome fit',
#  'Awesome jacket!',
#  'Awesome shirt',
#  'Awesome!',
#  'Awful',
#  'Awkward',
#  'Awkward fit',
#  'Beautiful',
#  'Beautiful and comfortable',
#  'Beautiful and flattering',
#  'Beautiful and slimming!',
#  'Beautiful and soft',
#  'Beautiful and timeless',
#  'Beautiful and unique',
# ...

# %%
set(train["Review Text"]) & set(test["Review Text"])
# Out:
# {"I bought this shirt at the store and after going home and trying it on, i promptly went online and ordered two more! i've gotten multiple compliments anytime i wear any of them. great for looking put together with no fuss. \r\npeople that have commented there's were destroyed in the wash didn't read the care label which says dry clean.",
#  'I purchased this and another eva franco dress during retailer\'s recent 20% off sale. i was looking for dresses that were work appropriate, but that would also transition well to happy hour or date night. they both seemed to be just what i was looking for. i ordered a 4 regular and a 6 regular, as i am usually in between sizes. the 4 was definitely too small. the 6 fit, technically, but was very ill fitting. not only is the dress itself short, but it is very short-waisted. i am only 5\'3", but it fe',
# ...

# %%
len(set(train["Review Text"]) & set(test["Review Text"]))
# Out:
# 4
