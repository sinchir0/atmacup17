# %% [markdown]
# # 目的
# LightGBMによる2ndStage

# %%
EXP_NAME = "e120-tune"
COMPETITION_NAME = "atmacup17"

DATA_PATH = "data"
ENV_PATH = "env_file"
MODEL_OUTPUT_PATH = f"trained_models/{EXP_NAME}"
TARGET_COL = "Recommended IND"

# experiment parameter
DEBUG = False
TRAINING = True
UPLOAD_DATA_TO_S3 = True
# UPLOAD_DATA_TO_KAGGLE = True
WANDB = True

# %%
import polars as pl
import numpy as np

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score

import lightgbm as lgb
# import optuna.integration.lightgbm as lgb

import seaborn as sns

# %%
pl.__version__
# Out:
# '1.0.0'

# %%
def resolve_path(base_path: str) -> str:
    import os

    cwd = os.getcwd()
    print(cwd)
    if cwd == f"/notebooks":
        print("Jupyter Kernel By VSCode!")
        return "kernel", f"/notebooks/{COMPETITION_NAME}/{base_path}"
    elif cwd == f"/notebooks/{COMPETITION_NAME}":
        print("nohup!")
        return base_path
    elif cwd == f"/notebooks/{COMPETITION_NAME}/{COMPETITION_NAME}/exp":
        print("Jupyter Lab!")
        return "nohup", f"../../{base_path}"
    elif cwd == f"/content":
        print("Google Colab!")
        return "colab", f"/content/drive/MyDrive/Kaggle/{COMPETITION_NAME}/{base_path}"
    elif cwd.startswith("/home/shinichiro.saito"):
        print("GCP!")
        return "GCP", f"/home/shinichiro.saito/{COMPETITION_NAME}/{base_path}"
    else:
        raise Exception("Unknown environment")


ENV_NAME, DATA_PATH = resolve_path(DATA_PATH)
print(DATA_PATH)
_, MODEL_OUTPUT_PATH = resolve_path(MODEL_OUTPUT_PATH)
print(MODEL_OUTPUT_PATH)
_, ENV_PATH = resolve_path(ENV_PATH)
# Out:
# /home/shinichiro.saito/atmacup17/exp
# GCP!
# /home/shinichiro.saito/atmacup17/data
# /home/shinichiro.saito/atmacup17/exp
# GCP!
# /home/shinichiro.saito/atmacup17/trained_models/e120-tune
# /home/shinichiro.saito/atmacup17/exp
# GCP!

# %%
import json

with open(f"{DATA_PATH}/rec_stratified_fold.json") as f:
    label_stratified_fold = json.load(f)

# %%
train = pl.read_csv(f"{DATA_PATH}/train_with_index.csv")
test = pl.read_csv(f"{DATA_PATH}/test_with_index.csv")
clothing_master = pl.read_csv(f"{DATA_PATH}/clothing_master.csv")

train = train.join(clothing_master, on="Clothing ID", how="left").with_columns(
    pl.col("index").replace(label_stratified_fold).alias("fold"),  # foldを追加する
    pl.col("Clothing ID").cast(pl.String),
)
test = test.join(clothing_master, on="Clothing ID", how="left").with_columns(
    pl.col("Clothing ID").cast(pl.String),
)

# %%
train
# Out:
# shape: (10_000, 12)
# ┌───────┬─────────────┬─────┬─────────────────┬───┬──────────┬─────────────────┬────────────┬──────┐
# │ index ┆ Clothing ID ┆ Age ┆ Title           ┆ … ┆ Division ┆ Department Name ┆ Class Name ┆ fold │
# │ ---   ┆ ---         ┆ --- ┆ ---             ┆   ┆ Name     ┆ ---             ┆ ---        ┆ ---  │
# │ i64   ┆ str         ┆ i64 ┆ str             ┆   ┆ ---      ┆ str             ┆ str        ┆ i64  │
# │       ┆             ┆     ┆                 ┆   ┆ str      ┆                 ┆            ┆      │
# ╞═══════╪═════════════╪═════╪═════════════════╪═══╪══════════╪═════════════════╪════════════╪══════╡
# │ 0     ┆ 0           ┆ 25  ┆ 3-season skirt! ┆ … ┆ General  ┆ Bottoms         ┆ Skirts     ┆ 2    │
# │ 1     ┆ 0           ┆ 39  ┆ Very cute       ┆ … ┆ General  ┆ Bottoms         ┆ Skirts     ┆ 2    │
# │ 2     ┆ 0           ┆ 42  ┆ Beautiful!      ┆ … ┆ General  ┆ Bottoms         ┆ Skirts     ┆ 1    │
# │       ┆             ┆     ┆ fruns small for ┆   ┆          ┆                 ┆            ┆      │
# │       ┆             ┆     ┆ typ…            ┆   ┆          ┆                 ┆            ┆      │
# │ 3     ┆ 0           ┆ 45  ┆ null            ┆ … ┆ General  ┆ Bottoms         ┆ Skirts     ┆ 0    │
# │ 4     ┆ 0           ┆ 57  ┆ Unique, pretty  ┆ … ┆ General  ┆ Bottoms         ┆ Skirts     ┆ 1    │
# │       ┆             ┆     ┆ asymmetric      ┆   ┆          ┆                 ┆            ┆      │
# │       ┆             ┆     ┆ skir…           ┆   ┆          ┆                 ┆            ┆      │
# │ …     ┆ …           ┆ …   ┆ …               ┆ … ┆ …        ┆ …               ┆ …          ┆ …    │
# │ 9995  ┆ 232         ┆ 57  ┆ Runs big on top ┆ … ┆ General  ┆ Dresses         ┆ Dresses    ┆ 1    │
# │ 9996  ┆ 232         ┆ 58  ┆ null            ┆ … ┆ General  ┆ Dresses         ┆ Dresses    ┆ 0    │
# │ 9997  ┆ 232         ┆ 60  ┆ I was really    ┆ … ┆ General  ┆ Dresses         ┆ Dresses    ┆ 1    │
# │       ┆             ┆     ┆ disappointed    ┆   ┆          ┆                 ┆            ┆      │
# │ 9998  ┆ 232         ┆ 62  ┆ Too heavy       ┆ … ┆ General  ┆ Dresses         ┆ Dresses    ┆ 1    │
# │ 9999  ┆ 232         ┆ 62  ┆ null            ┆ … ┆ General  ┆ Dresses         ┆ Dresses    ┆ 2    │
# └───────┴─────────────┴─────┴─────────────────┴───┴──────────┴─────────────────┴────────────┴──────┘

# %% [markdown]
# # feature engineering

# %% [markdown]
# ## DeBERTa xsmall oof pred

# %%
xsmall_oof = pl.read_csv(
    f"../trained_models/e004-0-1-2-ens/xsmall-fold-fix-oof.csv"
).rename({"valid_pred": "xsmall_pred"})

xsmall_pred = pl.read_csv(
    f"../trained_models/e004-0-1-2-ens/e004-0-1-2-ens-cv0.9590.csv"
)

# %%
train = train.join(
    xsmall_oof.select(pl.col(["index", "xsmall_pred"])), on="index", how="left"
)
test = test.with_columns(pl.Series(xsmall_pred).alias("xsmall_pred"))

# %% [markdown]
# # DeBERTa(all_info auxiliary loss) large oof pred

# %%
large_aux_oof_fold0 = pl.read_csv(
    "../trained_models/e032-lrg-fold0/valid_dataset_e032-lrg-fold0.csv"
)
large_aux_oof_fold1 = pl.read_csv(
    "../trained_models/e033-lrg-fold1/valid_dataset_e033-lrg-fold1.csv"
)
large_aux_oof_fold2 = pl.read_csv(
    "../trained_models/e034-lrg-fold2/valid_dataset_e034-lrg-fold2.csv"
)

large_aux_pred_fold0 = pl.read_csv(
    "../trained_models/e032-lrg-fold0/submission_e032-lrg-fold0_cv0.9720.csv"
)
large_aux_pred_fold1 = pl.read_csv(
    "../trained_models/e033-lrg-fold1/submission_e033-lrg-fold1_cv0.9715.csv"
)
large_aux_pred_fold2 = pl.read_csv(
    "../trained_models/e034-lrg-fold2/submission_e034-lrg-fold2_cv0.9669.csv"
)

large_aux_oof = pl.concat(
    [large_aux_oof_fold0, large_aux_oof_fold1, large_aux_oof_fold2], how="vertical"
)
large_aux_pred = (
    large_aux_pred_fold0 + large_aux_pred_fold1 + large_aux_pred_fold2
) / 3

# %%
train = train.join(
    large_aux_oof.select(pl.col(["index", "valid_pred"])), on="index", how="left"
).rename({"valid_pred": "large_aux_pred"})
test = test.with_columns(pl.Series(large_aux_pred).alias("large_aux_pred"))

# %% [markdown]
# # DeBERTa(all info) large

# %%
large_all_info_oof = pl.read_csv(f"../trained_models/e037-ens/large-oof.csv")
large_all_info_pred = pl.read_csv(f"../trained_models/e037-ens/ens37-cv0.9696.csv")

# %%
train = train.join(
    large_all_info_oof.select(pl.col(["index", "valid_pred"])), on="index", how="left"
).rename({"valid_pred": "large_all_info_pred"})
test = test.with_columns(pl.Series(large_all_info_pred).alias("large_all_info_pred"))

# %% [markdown]
# # tfidf

# %%
tfidf_oof = pl.read_csv(f"../trained_models/e-tfidf/oof_Title_tfidf_vec.csv")
tfidf_pred = pl.read_csv(f"../trained_models/e-tfidf/test_Title_tfidf_vec.csv")

# %%
train = train.join(tfidf_oof, on="index", how="left")
test = test.join(tfidf_pred, on="index", how="left")

# %% [markdown]
# # LLM Embedding

# %%
train_emb = np.load(f"{DATA_PATH}/train_embeddings_reduced.npy")
test_emb = np.load(f"{DATA_PATH}/test_embeddings_reduced.npy")

# %%
print(train_emb.shape)
print(test_emb.shape)
# Out:
# (10000, 300)
# (11155, 300)

# %%
train_emb = pl.DataFrame(train_emb, schema=[f"llm_{i}" for i in range(300)])
test_emb = pl.DataFrame(test_emb, schema=[f"llm_{i}" for i in range(300)])

# %%
train = pl.concat([train, train_emb], how="horizontal")
test = pl.concat([test, test_emb], how="horizontal")

# %% [markdown]
# # Rating

# %%
rating_oof_fold0 = pl.read_csv(
    "../trained_models/e042-rating-fold0/valid_dataset_e042-rating-fold0.csv"
)
rating_oof_fold1 = pl.read_csv(
    "../trained_models/e043-rating-fold1/valid_dataset_e043-rating-fold1.csv"
)
rating_oof_fold2 = pl.read_csv(
    "../trained_models/e044-rating-fold2/valid_dataset_e044-rating-fold2.csv"
)

rating_pred_fold0 = pl.read_csv(
    "../trained_models/e042-rating-fold0/submission_e042-rating-fold0_cv0.9314.csv"
)
rating_pred_fold1 = pl.read_csv(
    "../trained_models/e043-rating-fold1/submission_e043-rating-fold1_cv0.9349.csv"
)
rating_pred_fold2 = pl.read_csv(
    "../trained_models/e044-rating-fold2/submission_e044-rating-fold2_cv0.9368.csv"
)

rating_aux_oof = pl.concat(
    [rating_oof_fold0, rating_oof_fold1, rating_oof_fold2], how="vertical"
)

# %%
import numpy as np


def denormalize(normalized_array, min_value=0, max_value=4):
    # 0~1の範囲の正規化された値をもとに戻す
    return normalized_array * (max_value - min_value) + min_value


rating_pred_fold0 = denormalize(rating_pred_fold0)
rating_pred_fold1 = denormalize(rating_pred_fold1)
rating_pred_fold2 = denormalize(rating_pred_fold2)

# %%
rating_aux_pred = (rating_pred_fold0 + rating_pred_fold1 + rating_pred_fold2) / 3

# %%
train = train.join(
    rating_aux_oof.select(pl.col(["index", "valid_pred"])), on="index", how="left"
).rename({"valid_pred": "rating_pred"})
test = test.with_columns(pl.Series(rating_aux_pred).alias("rating_pred"))

# %% [markdown]
# # Text Stat

# %%
train = train.with_columns(
    pl.concat_str([pl.col("Title"), pl.col("Review Text")], separator=" ").alias(
        "full_text"
    )
)

test = test.with_columns(
    pl.concat_str([pl.col("Title"), pl.col("Review Text")], separator=" ").alias(
        "full_text"
    )
)

# %%
with open(f"{DATA_PATH}/train_index_spelling_errors_cnt_pyspell.json") as f:
    train_essay_id_spelling_errors_cnt = json.load(f)

with open(f"{DATA_PATH}/test_index_spelling_errors_cnt_pyspell.json") as f:
    test_essay_id_spelling_errors_cnt = json.load(f)

# %%
import textstat


def get_len_chars(col: str) -> pl.Expr:
    return pl.col(col).str.len_chars().alias(f"{col}_len_chars")


def get_word_num(col: str) -> pl.Expr:
    return (
        pl.col(col)
        .map_elements(lambda x: len(x.split()), return_dtype=pl.Int32)
        .alias(f"{col}_word_num")
    )


def train_count_spelling_errors() -> pl.Expr:
    return (
        pl.col("index")
        .replace_strict(train_essay_id_spelling_errors_cnt, return_dtype=pl.Int64)
        .alias("spelling_errors_cnt")
    )


def test_count_spelling_errors() -> pl.Expr:
    return (
        pl.col("index")
        .replace_strict(test_essay_id_spelling_errors_cnt, return_dtype=pl.Int64)
        .alias("spelling_errors_cnt")
    )


def rate_spelling_errors_per_word() -> pl.Expr:
    return (pl.col("spelling_errors_cnt") / pl.col("full_text_word_num")).alias(
        "rate_spelling_errors_per_word"
    )


train = train.with_columns(
    get_len_chars("Title"),
    get_len_chars("Review Text"),
    get_len_chars("full_text"),
    get_word_num("Title"),
    get_word_num("Review Text"),
    get_word_num("full_text"),
    train_count_spelling_errors(),
).with_columns(rate_spelling_errors_per_word())

test = test.with_columns(
    get_len_chars("Title"),
    get_len_chars("Review Text"),
    get_len_chars("full_text"),
    get_word_num("Title"),
    get_word_num("Review Text"),
    get_word_num("full_text"),
    test_count_spelling_errors(),
).with_columns(rate_spelling_errors_per_word())

# %% [markdown]
# # Training

# %%
USE_COL = [
    "Clothing ID",
    "Age",
    "Positive Feedback Count",
    "Division Name",
    "Department Name",
    "Class Name",
    "xsmall_pred",
    "large_aux_pred",
    "large_all_info_pred",
    "rating_pred",
]
USE_COL += [
    "Title_len_chars",
    "Review Text_len_chars",
    "full_text_len_chars",
    "Title_word_num",
    "Review Text_word_num",
    "full_text_word_num",
    "spelling_errors_cnt",
    "rate_spelling_errors_per_word",
]
USE_COL += [f"Title_tfidf_{i}" for i in range(100)]
USE_COL += [f"llm_{i}" for i in range(300)]
CATEGORICAL_FEATURE = ["Clothing ID", "Division Name", "Department Name", "Class Name"]
TARGET_COL = "Recommended IND"
FOLD_NUM = 3
SEED = 42

# %%
# Categorical型への変換
train = train.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))
test = test.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))

# %%
# LightGBMで用いるパラメータを指定
params = {
    "objective": "binary",
    # "metric": "auc",
    "max_depth": -1,
    "min_data_in_leaf": 10,  # 1つの葉に入る最小のデータ数
    "num_leaves": 24,  # 2**max_depthより少し小さめにすると過学習を防げる
    "learning_rate": 0.01,  # 1回のiterationで学習を進める割合、大きいと学習が早く終わる。小さいと学習は長いが高精度になりやすい。
    "bagging_freq": 5,  # 指定した回数ごとにbaggingを行う
    "feature_fraction": 0.9,  # 1回のiterationで利用する特徴量(列方向)の割合
    "bagging_fraction": 0.8,  # 1回のiterationで利用するデータ(行方向)の割合
    "verbose": -1,  # 出力するログレベルの変更、-1はFatalなログのみを出力
    "seed": SEED,  # ランダムシードの固定
    "lambda_l1": 0.4,  # 正則化のためのパラメータ
    "lambda_l2": 0.4,  # 正則化のためのパラメータ
}

# %%
# テストデータに対する推論、特徴量重要度(後述)を計算するために、モデルを保存するobjectを作成
models = []

# Cross Validationによる学習の実施
for fold in range(FOLD_NUM):
    print(f"Start fold {fold}")

    # foldごとにtrainとvalidに分ける
    train_fold = train.filter(pl.col("fold") != fold)
    valid_fold = train.filter(pl.col("fold") == fold)

    # X(説明変数)とy(目的変数)に分ける
    X_train = train_fold.select(USE_COL)
    X_valid = valid_fold.select(USE_COL)
    y_train = train_fold.select(TARGET_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # LightGBMが認識可能な形にデータセットを変換
    lgb_train = lgb.Dataset(X_train.to_pandas(), y_train.to_pandas())
    lgb_eval = lgb.Dataset(
        X_valid.to_pandas(), y_valid.to_pandas(), reference=lgb_train
    )

    # モデルの学習
    model = lgb.train(
        params,
        lgb_train,
        num_boost_round=10000,  # 学習のiteration回数
        valid_sets=[lgb_train, lgb_eval],
        callbacks=[
            lgb.early_stopping(
                stopping_rounds=100
            ),  # Early stopingの回数、binary_loglossが改善しないiterationが100回続いたら学習を止める
            lgb.log_evaluation(100),  # 指定したiteration回数ごとにlogを出力する
        ],
    )

    # モデルを保存
    models.append([fold, model])
# Out:
# [I 2024-08-31 08:56:51,105] A new study created in memory with name: no-name-32084599-be0a-445e-b85b-73340f425daa
# Start fold 0
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.224271	valid_1's binary_logloss: 0.22976
# [200]	valid_0's binary_logloss: 0.169	valid_1's binary_logloss: 0.178916
# [300]	valid_0's binary_logloss: 0.147909	valid_1's binary_logloss: 0.163567
# [400]	valid_0's binary_logloss: 0.134822	valid_1's binary_logloss: 0.159955
# [500]	valid_0's binary_logloss: 0.125174	valid_1's binary_logloss: 0.159682
# Early stopping, best iteration is:
# [448]	valid_0's binary_logloss: 0.130045	valid_1's binary_logloss: 0.159373
# feature_fraction, val_score: 0.159373:  14%|#4        | 1/7 [00:03<00:18,  3.02s/it][I 2024-08-31 08:56:54,132] Trial 0 finished with value: 0.1593732998608482 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.1593732998608482.
# feature_fraction, val_score: 0.159373:  14%|#4        | 1/7 [00:03<00:18,  3.02s/it]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.222425	valid_1's binary_logloss: 0.228812
# [200]	valid_0's binary_logloss: 0.167355	valid_1's binary_logloss: 0.178082
# [300]	valid_0's binary_logloss: 0.146461	valid_1's binary_logloss: 0.163953
# [400]	valid_0's binary_logloss: 0.133615	valid_1's binary_logloss: 0.160769
# [500]	valid_0's binary_logloss: 0.123801	valid_1's binary_logloss: 0.160277
# feature_fraction, val_score: 0.159373:  29%|##8       | 2/7 [00:06<00:15,  3.15s/it][I 2024-08-31 08:56:57,379] Trial 1 finished with value: 0.1601492193744531 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.1593732998608482.
# feature_fraction, val_score: 0.159373:  29%|##8       | 2/7 [00:06<00:15,  3.15s/it]
# Early stopping, best iteration is:
# [451]	valid_0's binary_logloss: 0.128318	valid_1's binary_logloss: 0.160149
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.228334	valid_1's binary_logloss: 0.233197
# [200]	valid_0's binary_logloss: 0.17137	valid_1's binary_logloss: 0.181139
# [W 2024-08-31 08:56:58,874] Trial 2 failed with parameters: {'feature_fraction': 0.5} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/optimize.py", line 238, in __call__
#     booster = lgb.train(self.lgbm_params, train_set, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/lightgbm/engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "/opt/conda/lib/python3.10/site-packages/lightgbm/basic.py", line 4136, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2024-08-31 08:56:58,879] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 25
#      20 lgb_eval = lgb.Dataset(
#      21     X_valid.to_pandas(), y_valid.to_pandas(), reference=lgb_train
#      22 )
#      24 # モデルの学習
# ---> 25 model = lgb.train(
#      26     params,
#      27     lgb_train,
#      28     num_boost_round=10000,  # 学習のiteration回数
#      29     valid_sets=[lgb_train, lgb_eval],
#      30     callbacks=[
#      31         lgb.early_stopping(
#      32             stopping_rounds=100
#      33         ),  # Early stopingの回数、binary_loglossが改善しないiterationが100回続いたら学習を止める
#      34         lgb.log_evaluation(100),  # 指定したiteration回数ごとにlogを出力する
#      35     ],
#      36 )
#      38 # モデルを保存
#      39 models.append([fold, model])
#
# File /opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/_train.py:138, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, feature_name, categorical_feature, keep_training_booster, callbacks, time_budget, sample_size, study, optuna_callbacks, model_dir, verbosity, show_progress_bar, optuna_seed)
#     116 _imports.check()
#     118 auto_booster = LightGBMTuner(
#     119     params=params,
#     120     train_set=train_set,
#    (...)
#     136     optuna_seed=optuna_seed,
#     137 )
# --> 138 auto_booster.run()
#     139 return auto_booster.get_best_booster()
#
# File /opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/optimize.py:496, in _LightGBMBaseTuner.run(self)
#     493 # Sampling.
#     494 self.sample_train_set()
# --> 496 self.tune_feature_fraction()
#     497 self.tune_num_leaves()
#     498 self.tune_bagging()
#
# File /opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/optimize.py:521, in _LightGBMBaseTuner.tune_feature_fraction(self, n_trials)
#     518 param_values = np.linspace(0.4, 1.0, n_trials).tolist()
#     520 sampler = optuna.samplers.GridSampler({param_name: param_values}, seed=self._optuna_seed)
# --> 521 self._tune_params([param_name], len(param_values), sampler, "feature_fraction")
#
# File /opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/optimize.py:604, in _LightGBMBaseTuner._tune_params(self, target_param_names, n_trials, sampler, step_name)
#     602     _timeout = None
#     603 if _n_trials > 0:
# --> 604     study.optimize(
#     605         objective,
#     606         n_trials=_n_trials,
#     607         timeout=_timeout,
#     608         catch=(),
#     609         callbacks=self._optuna_callbacks,
#     610     )
#     612 if pbar:
#     613     pbar.close()
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# File /opt/conda/lib/python3.10/site-packages/optuna_integration/_lightgbm_tuner/optimize.py:238, in _OptunaObjective.__call__(self, trial)
#     236 kwargs = copy.copy(self.lgbm_kwargs)
#     237 kwargs["valid_sets"] = self._copy_valid_sets(kwargs["valid_sets"])
# --> 238 booster = lgb.train(self.lgbm_params, train_set, **kwargs)
#     240 val_score = self._get_booster_best_score(booster)
#     241 elapsed_secs = time.time() - start_time
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:307, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     295 for cb in callbacks_before_iter:
#     296     cb(
#     297         callback.CallbackEnv(
#     298             model=booster,
#    (...)
#     304         )
#     305     )
# --> 307 booster.update(fobj=fobj)
#     309 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     310 # check evaluation result.
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:4136, in Booster.update(self, train_set, fobj)
#    4133 if self.__set_objective_to_none:
#    4134     raise LightGBMError("Cannot update due to null objective function.")
#    4135 _safe_call(
# -> 4136     _LIB.LGBM_BoosterUpdateOneIter(
#    4137         self._handle,
#    4138         ctypes.byref(is_finished),
#    4139     )
#    4140 )
#    4141 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4142 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
# 学習データ全体に対する推論結果を保存するobjectを作成
oof = np.zeros((len(train)))

scores = []
# foldの値と学習済みモデルを利用し、モデルの評価を行う
for fold, model in models:
    valid_fold = train.filter(pl.col("fold") == fold)

    X_valid = valid_fold.select(USE_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # validデータに対する推論
    y_valid_pred = model.predict(
        X_valid.to_pandas(), num_iteration=model.best_iteration
    )

    score = roc_auc_score(y_valid, y_valid_pred)
    scores.append(score)
    print(f"fold {fold} Score: {score}")

    is_valid = train.get_column("fold") == fold
    oof[is_valid] = y_valid_pred
# Out:
# fold 0 Score: 0.972591441111924
# fold 1 Score: 0.9690468019730518
# fold 2 Score: 0.9663450911235868

# %%
cv_score = roc_auc_score(train.get_column(TARGET_COL), oof)
cv_score
# foldごとの平均をとる
# cv_score = np.mean(scores)
# cv_score
# Out:
# 0.9689382646029794

# %%
import pandas as pd

feature_importances = [
    model.feature_importance(importance_type="gain") for _, model in models
]
feature_importances_df = pd.DataFrame(feature_importances, columns=USE_COL)

order = feature_importances_df.mean().sort_values(ascending=False).index.tolist()

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 100))
sns.boxplot(data=feature_importances_df, orient="h", order=order);

# %%
pred = np.array([model.predict(test[USE_COL].to_pandas()) for _, model in models])
pred = np.mean(pred, axis=0)
pred
# Out:
# array([0.99400597, 0.55142058, 0.99517645, ..., 0.99513591, 0.99461869,
#        0.99516921])

# %%
import os

os.makedirs(MODEL_OUTPUT_PATH, exist_ok=True)

sample_submission = pl.read_csv(f"{DATA_PATH}/sample_submission.csv")

if DEBUG:
    sample_submission = sample_submission.head(100)

(
    sample_submission.with_columns(pl.Series(pred).alias("target")).write_csv(
        f"{MODEL_OUTPUT_PATH}/submission_{EXP_NAME}_cv{cv_score:.4f}.csv"
    )
)
